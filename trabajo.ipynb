# %%
url= "https://listado.mercadolibre.com.pe/computacion/laptops/"
uclient= urlopen(url)
pagehtml=uclient.read()
uclient.close()
pagesoup=soup(pagehtml, "html.parser")
c=pagesoup.findAll("li",{"class":"ui-search-layout__item"})
c[1].div.a["title"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b182cc8ac1d8> in <module>
#       1 url= "https://listado.mercadolibre.com.pe/computacion/laptops/"
# ----> 2 uclient= urlopen(url)
#       3 pagehtml=uclient.read()
#       4 uclient.close()
#       5 pagesoup=soup(pagehtml, "html.parser")
#
# NameError: name 'urlopen' is not defined

# %%
titulos=[]
precio_actual=[]
descuento=[]
precio_anterior=[]
detalles=[]

#find busca un elemento
#findAll crea una lista

for i in range(0,4):
    url="https://listado.mercadolibre.com.pe/computacion/laptops/"+"_Desde_"+str(i*50+1)
    uclient=urlopen(url)
    pagehtml=uclient.read()
    uclient.close()
    pagesoup=soup(pagehtml, "html.parser")
    c=pagesoup.findAll("li",{"class":"ui-search-layout__item"})

    for i in range(0,len(c)):
        
        titulo=c[i].div.a["title"]
        #mas especifico
        titulo=c[i].find("div",{"ui-search-item__group ui-search-item__group--title"}).a["title"] #[0] ya que guarda todo en una lista de un elemento y agarramos ese element                titulos.append(titulo)
        titulos.append(titulo)
        if len(c[i].findAll("span",{"price-tag-fraction"})) == 2:
            
            precioactual=c[i].findAll("span",{"price-tag-fraction"})[1].text
            precioanterior=c[i].findAll("span",{"price-tag-fraction"})[0].text
            descuento1=c[i].find("span",{"class":"ui-search-price__discount"}).text
            precio_actual.append(precioactual)
            precio_anterior.append(precioanterior)
            descuento.append(descuento1)

        elif len(c[i].findAll("span",{"price-tag-fraction"})) == 1:
            descuento1=0
            descuento.append(descuento1)
            precioactual=c[i].findAll("span",{"price-tag-fraction"})[0].text
            precioanterior=c[i].findAll("span",{"price-tag-fraction"})[0].text
            precio_actual.append(precioactual)
            precio_anterior.append(precioanterior)


        detalles1=c[i].findAll("div",{"class":"ui-search-item__group ui-search-item__group--details"})
        if detalles1==[]:
            detalles1="na"
            detalles.append(detalles1)
        else:
            detalles1=detalles1[0].text
            detalles.append(detalles1)
            
for i in range(0,len(precio_actual)):
    precio_actual[i]=float(precio_actual[i].replace(".",""))
    precio_anterior[i]=float(precio_anterior[i].replace(".",""))
    
            
df=pd.DataFrame({"Nombre":titulos,"Detalles":detalles,"Precio actual":precio_actual,"Precio anterior":precio_anterior
                 ,"Descuento":descuento},index=list(range(1,len(titulos)+1))) 

df.to_csv("trabajocsv.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-352dd0343e8d> in <module>
#      26             precioactual=c[i].findAll("span",{"price-tag-fraction"})[1].text
#      27             precioanterior=c[i].findAll("span",{"price-tag-fraction"})[0].text
# ---> 28             descuento1=c[i].find("span",{"class":"ui-search-price__discount"}).text
#      29             precio_actual.append(precioactual)
#      30             precio_anterior.append(precioanterior)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df
# Out:
#                                                 Nombre  \
# 1    Oferta! Hp / Dell/ Lenovo Ci5 4gb Hdmi 14  Ssd...
# 2    Laptop Hp/dell Empresarial Ci7, 4gb, 1tb, Vide...
# 3    Laptop Hp Elitebook 840 G2, Ci5, 5ta.gen, 5300...
# 4    Laptop Empresarial Hp Elitebook 840 G3 - Ci5 -...
# 5    Laptop Hp/dell Empresarial Ci7, 8gb, 1tb, Vide...
# ..                                                 ...
# 202       Laptop Compaq Presario F700 F754la Repuestos
# 203  Macbook Pro Touch Bar 15 256gb 2019 I7 Sellado...
# 204              Laptop Toshiba Satellite A505 Core I7
# 205  Laptop I7-3ra Gen, Hp Folio 9470m , Ram 4gb, D...
# 206  Cargador Para Mac Pro De 45w Original No Gener...
#
#                    Detalles  Precio actual  Precio anterior Descuento
# 1              Usado - Lima          999.0           1599.0   37% OFF
# 2    Reacondicionado - Lima         1389.0           1986.0   30% OFF
# 3    Reacondicionado - Lima         1389.0           1986.0   30% OFF
# 4    Reacondicionado - Lima         1689.0           2415.0   30% OFF
# 5              Usado - Lima         1390.0           1987.0   30% OFF
# ..                      ...            ...              ...       ...
# 202            Usado - Lima           99.0             99.0         0
# 203                      na         8400.0           8400.0         0
# 204            Usado - Lima         1000.0           1000.0         0
# 205            Usado - Lima         1650.0           1650.0         0
# 206            Usado - Lima          300.0            300.0         0
#
# [206 rows x 5 columns]
